# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_dados = pd.read_csv('tabela-fipe-historico-precos.csv')

# %%
df_dados.shape
# Out:
# (466020, 8)

# %%
df_dados.head()
# Out:
#    Unnamed: 0 codigoFipe  marca          modelo  anoModelo  mesReferencia  \
# 0           0   038003-2  Acura  Integra GS 1.8       1992             11
# 1           1   038001-6  Acura         NSX 3.0       1995              3
# 2           2   038003-2  Acura  Integra GS 1.8       1992              3
# 3           3   038002-4  Acura  Legend 3.2/3.5       1998              5
# 4           4   038002-4  Acura  Legend 3.2/3.5       1998              2
#
#    anoReferencia     valor
# 0           2016 13,041.00
# 1           2013 52,339.00
# 2           2018 12,423.00
# 3           2016 31,067.00
# 4           2019 26,381.00

# %%
df_dados.tail()
# Out:
#         Unnamed: 0 codigoFipe marca                         modelo  anoModelo  \
# 466015      544147   061001-1  Walk  Buggy  Walk Sport 1.6 8V 58cv       2011
# 466016      544148   061001-1  Walk  Buggy  Walk Sport 1.6 8V 58cv       2022
# 466017      544149   061001-1  Walk  Buggy  Walk Sport 1.6 8V 58cv       2011
# 466018      544150   061001-1  Walk  Buggy  Walk Sport 1.6 8V 58cv       2022
# 466019      544151   061001-1  Walk  Buggy  Walk Sport 1.6 8V 58cv       2022
#
#         mesReferencia  anoReferencia     valor
# 466015              2           2015 24,811.00
# 466016              6           2006 31,503.00
# 466017              8           2016 23,582.00
# 466018              7           2007 31,990.00
# 466019              4           2009 34,425.00

# %%
df_dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466020 entries, 0 to 466019
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     466020 non-null  int64
#  1   codigoFipe     466020 non-null  object
#  2   marca          466020 non-null  object
#  3   modelo         466020 non-null  object
#  4   anoModelo      466020 non-null  int64
#  5   mesReferencia  466020 non-null  int64
#  6   anoReferencia  466020 non-null  int64
#  7   valor          466020 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 28.4+ MB

# %%
df_dados.isnull().sum()
# Out:
# Unnamed: 0       0
# codigoFipe       0
# marca            0
# modelo           0
# anoModelo        0
# mesReferencia    0
# anoReferencia    0
# valor            0
# dtype: int64

# %%
df_dados.describe()
# Out:
#        Unnamed: 0  anoModelo  mesReferencia  anoReferencia        valor
# count  466,020.00 466,020.00     466,020.00     466,020.00   466,020.00
# mean   272,398.09   2,008.97           6.45       2,015.18   115,745.60
# std    159,700.92      10.00           3.42           5.68   325,073.71
# min          0.00   1,985.00           1.00       2,001.00     1,871.00
# 25%    132,377.00   2,000.00           4.00       2,011.00    19,388.00
# 50%    275,044.50   2,009.00           6.00       2,017.00    39,416.50
# 75%    408,696.25   2,020.00           9.00       2,020.00    84,794.50
# max    544,151.00   2,023.00          12.00       2,022.00 8,407,082.00

# %%
df_dados['anoModelo'].hist()
# Out:
# <Axes: >

# %%
df_dados['valor'].describe()
# Out:
# count     466,020.00
# mean      115,745.60
# std       325,073.71
# min         1,871.00
# 25%        19,388.00
# 50%        39,416.50
# 75%        84,794.50
# max     8,407,082.00
# Name: valor, dtype: float64

# %%
df_dados['valor'].hist()
# Out:
# <Axes: >

# %%
df_dados.groupby('marca')['valor'].mean()
# Out:
# marca
# ASTON MARTIN        933,659.50
# Acura                30,653.20
# Agrale              107,277.97
# Alfa Romeo           36,435.07
# Asia Motors           7,114.45
# Audi                143,088.92
# BMW                 237,271.89
# BRM                  32,903.93
# BYD                 428,662.27
# Baby                 31,980.80
# Bugre                22,493.54
# CHANA                22,137.69
# CHANGAN              23,009.81
# Cadillac             69,546.85
# Caoa Chery           51,365.65
# Chrysler             55,037.25
# Citroën              39,141.01
# Cross Lander         64,451.60
# Daewoo               11,121.40
# Daihatsu             10,014.43
# Dodge                49,034.72
# EFFA                 27,702.90
# Engesa               32,518.15
# Envemo               25,238.81
# Ferrari           1,033,705.96
# Fiat                 40,614.35
# Fibravan             40,083.92
# Ford                 37,021.10
# Fyber                42,971.63
# GEELY                33,018.03
# GM - Chevrolet       44,237.61
# GREAT WALL           46,610.19
# Gurgel               10,294.86
# HAFEI                22,667.65
# HITECH ELECTRIC     105,926.01
# Honda                47,179.21
# Hyundai              53,938.80
# Isuzu                14,314.11
# JAC                  66,895.72
# JINBEI               50,488.17
# Jaguar              255,083.81
# Jeep                102,272.77
# Kia Motors           65,174.93
# LAMBORGHINI       2,290,423.31
# LIFAN                46,993.23
# LOBINI              111,949.99
# Lada                  7,853.28
# Land Rover          340,834.48
# Lexus               191,059.56
# Lotus                67,404.61
# MG                   82,934.32
# MINI                145,737.46
# Mahindra             78,575.01
# Maserati            450,166.42
# Matra                39,558.84
# Mazda                22,187.71
# Mclaren           2,814,183.72
# Mercedes-Benz       241,350.75
# Mercury              12,902.76
# Mitsubishi           64,588.05
# Nissan               48,756.31
# Peugeot              32,061.58
# Plymouth             13,876.57
# Pontiac              31,233.81
# Porsche             497,956.76
# RAM                 441,932.74
# RELY                 35,164.23
# Renault              32,459.58
# Rolls-Royce       3,719,299.53
# Rover                26,060.67
# SHINERAY             32,578.08
# SSANGYONG            82,253.92
# Saab                 17,405.22
# Saturn               10,980.04
# Seat                 14,225.54
# Subaru               54,710.40
# Suzuki               39,676.72
# Toyota               57,623.35
# Troller              29,814.13
# VW - VolksWagen      39,789.24
# Volvo                95,209.18
# Wake                 49,792.89
# Walk                 37,806.98
# smart                61,349.76
# Name: valor, dtype: float64
